# %% [markdown]
# # **MatPlotlib**
# The link below is a page of MatPlotLib examples<br>
# https://matplotlib.org/examples/

# %% [markdown]
# # **Introduction to Matplotlib**

# %% [markdown]
# Matplotlib is a very powerful plotting library useful for those working with Python and NumPy. The most used module of Matplotib is Pyplot which provides an interface like MATLAB. It uses Python and it is open source.

# %% [markdown]
# Install the matplotlib library

# %%
# !pip install -U matplotlib
# Out:
# Requirement already up-to-date: matplotlib in c:\anaconda3\lib\site-packages (3.4.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.16 in c:\anaconda3\lib\site-packages (from matplotlib) (1.18.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7 in c:\anaconda3\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# WARNING: You are using pip version 20.2.2; however, version 21.1.2 is available.
# You should consider upgrading via the 'c:\anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied, skipping upgrade: pyparsing>=2.2.1 in c:\anaconda3\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in c:\anaconda3\lib\site-packages (from matplotlib) (7.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %% [markdown]
# # **Import Matplotlib**
# Notice that Matplotlib is installed as plt. This is done to make it easier to type code. <br>
# Instead of having to add the full library name each time you use a matplotlib command, you can use plt.
# <br>
# The import "as" works with any import statement.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # **Make a simple plot**

# %%
#Plot a set of 5 points on a graph
plt.plot([2,4,6,8,10], [1,3,5,7,9])
#Use show to print it
plt.show()

# %% [markdown]
# 1. Plot the following points
# >(1,7), (5,6), (10,5), (15, 4), (20, 3), (25, 2), (30,1)

# %%
plt.plot([(1,7), (5,6), (10,5), (15, 4), (20, 3), (25, 2), (30,1)])
#Use show to print it
plt.show()

# %% [markdown]
# # **Plot from Python Lists**

# %%
#Plot a set of 5 points on a graph
#The points can be lists
x_coordinate = [2,4,6,8,10]
y_coordinate = [1,3,5,7,9]
plt.plot(x_coordinate, y_coordinate)
#Use show to print it
plt.show()

# %% [markdown]
# Plot the following lists. <br>
# list1 along the x axis <br>
# list2 along the y axis <br>
# >list1 = [22,33,44,55,66,77] <br>
# >list2 = [1, 4, 16, 55, 67, 98]

# %%
list1 = [22,33,44,55,66,77]
list2 = [1, 4, 16, 55, 67, 98]
plt.plot(list1, list2)
#Use show to print it
plt.show()

# %% [markdown]
# # **Add titles and labels**

# %%
list1 = [22,33,44,55,66,77]
list2 = [1, 4, 16, 20, 23, 98]
plt.plot(list1, list2)

#add a title to the plot
plt.title("Simple Plot")
#add x and y labels to a plot
plt.xlabel("list1")
plt.ylabel("list2")
plt.show()

# %% [markdown]
# 1. Plot the following lists
# > list_x = [33.23,34,32.65,65.4,90]<br>
# >list_y = [2.32,0.33,2.021,55.0,65.33]<br>
# 2. Add a title and x and y axis labels to the plot

# %%
list_x = [33.23,34,32.65,65.4,90]
list_y = [2.32,0.33,2.021,55.0,65.33]
plt.plot(list_x, list_y)
plt.title("Sample plot")
plt.xlabel("list x")
plt.ylabel("list y")
plt.show()

# %% [markdown]
# # **Change the size of a figure**
# Change the size of a figure with:<br>
# plt.figure(figsize=(x dimension, y dimension)

# %%
list1 = [22,33,44,55,66,77]
list2 = [1, 4, 3.4, 15.6, 3, 98]
#plt.figure has to come before the first plt.plot statement
plt.figure(figsize=(10,3))
plt.plot(list1, list2)

#add a title to the plot
plt.title("Simple Plot")
#add x and y labels to a plot
plt.xlabel("list1")
plt.ylabel("list2")
plt.show()

# %% [markdown]
# 1. Create a plot of a set of 10 points
# 2. Change the figure to have dimensions 8x2

# %%
list1 = [20,25,33,36,39,40,45,50]
list2 = [1,2,3,4,5,6,7,8]
plt.figure(figsize=(8,2))
plt.plot(list1,list2)

# %% [markdown]
# # **Change the format of the line in a plot**
# When plotting a line, the color and the type of line can be specified using:
# >plt.plot(x_points, y_points, "color-shape")<br>
# **Color choices are**:<br>
# b = blue<br>
# g = green<br>
# r= red<br>
# c = cyan<br>
# m = magenta<br>
# y = yellow<br>
# k = black<br>
# w = white<br>
# grey = '0.##' -->  # =  0-1<br>
# **OR**<br>
# color='######' -->  # = 0-f numbers<br>
# <br>
# **Types of lines**<br>
# o --> point<br>
# '-' --> --------<br>
# '-.' --> -.-.-.-.<br>
# ':' --> .........<br>
# '+' --> + + + + + <br>
# 'x' --> x x x x x <br>

# %%
#Changing the format of a line in a plot
list1 = [22,33,44,55,66,77]
list2 = [1, 4, 3.4, 15.6, 3, 98]
list3 = [10,33,44,50,60,65]
list4 = [10, 14, 23.4, 5.6, 30, 98]
list5 = [1,2,31,44,50,60]
list6 = [10,20,30,40,50,60]
list7 = [12,22,32,42,55,63]
list8 = [13,24,35,46,57,68]
#plt.figure has to come before the first plt.plot statement
plt.figure(figsize=(10,3))
plt.plot(list1, list2, 'r-')
plt.plot(list3, list4, 'b--')

#'+' plots the points as a '+'
plt.plot(list5, list6, 'g+')
#the 'o' plots dots for each point
plt.plot(list7, list8, 'mo')

#add a title to the plot
plt.title("Simple Plot")
plt.show()

# %% [markdown]
# Links to Matplotlib colors and line sytles
#
# https://matplotlib.org/gallery/lines_bars_and_markers/line_styles_reference.html
#
# https://matplotlib.org/3.1.1/tutorials/colors/colors.html

# %% [markdown]
# 1. Plot the following points:
# > list_x = [13,24,35,46,57,68]<br>
# >list_y = [12,22,32,42,55,63]<br>
#
# The plot should have:
# *   Dimensions 10, 4
# *   A title
#
# *   Labels for the x and y axis
# *   The line of the data points should be red
#
#
# *   The line should be of the form '--'

# %%
list_x = [13,24,35,46,57,68]
list_y = [12,22,32,42,55,63]
plt.figure(figsize=(10,4))
plt.title("My Plot!")
plt.xlabel("My X")
plt.ylabel("My Y")
plt.plot(list_x, list_y, 'r--')

# %% [markdown]
# ### Types of inputs to plotting functions
# All of plotting functions expect <b>numpy.array</b> or <b>list</b> as input. Classes that are 'array-like' such as <b>pandas</b> data objects and <b>numpy.matrix</b> may or may not work as intended. It is best to convert these to numpy.array objects prior to plotting.
#
# ## Getting Started with Pyplot
# Pyplot is a module of Matplotlib which provides simple functions to add plot elements like lines, images, text, etc. to the current axes in the current figure.
#
# ### Make a simple plot
# Here we import Matplotlib’s Pyplot module and Numpy library as most of the data that we will be working with will be in the form of arrays only.

# %%
import numpy as np
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
plt.plot(x, x**3, label='cubic') # Plot more data on the axes...
plt.xlabel('x label') # Add an x-label to the axes.
plt.ylabel('y label') # Add an y-label to the axes.
plt.title("Simple Plot") # Add a title to the axes.
plt.legend() # Add a legend.
plt.show()  # Show the plot

# %% [markdown]
# We pass two arrays as our input arguments to Pyplot’s <i>plot()</i> method and use <i>show()</i> method to invoke the required plot. Here note that the first array appears on the x-axis and second array appears on the y-axis of the plot. Now that our first plot is ready, let us add the title, and name x-axis and y-axis using methods <i>title()</i>, <i>xlabel()</i> and <i>ylabel()</i> respectively.
#
# We can also specify the size of the figure using method <i>figure()</i> and passing the values as a tuple of the length of rows and columns to the argument <i>figsize</i>

# %%
x = np.linspace(0, 2, 100)

plt.figure(figsize = (15,10))  # Set Figure size 
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
plt.plot(x, x**3, label='cubic') # Plot more data on the axes...
plt.xlabel('x label') # Add an x-label to the axes.
plt.ylabel('y label') # Add an y-label to the axes.
plt.title("Simple Plot") # Add a title to the axes.
plt.legend() # Add a legend.
plt.show()  # Show the plot

# %%
import pandas as pd
df = pd.read_csv('UN.csv')
df
# Plot population vs area
country = df['country'].to_numpy()
area = df['area'].to_numpy()
population = df['population'].to_numpy()
plt.figure(figsize = (15,10))  # Set Figure size 
plt.plot(area, population, 'go', label='population vs area')  # Plot some data on the (implicit) axes.
plt.xlabel('Area') # Add an x-label to the axes.
plt.ylabel('Population') # Add an y-label to the axes.
plt.title("Population vs Area for UN countries") # Add a title to the axes.
plt.legend() # Add a legend.
plt.show()  # Show the plot

# %% [markdown]
# ## **Multiple Plots in one Figure**
# To add multiple plots in one figure, use the plt.subplot function. <br><br>
# plt.subplot(number-of-rows, number-of-columns, index)<br><br>
# Note: index begins with 1

# %%
#Adding multiplots to one figure
plt.subplot(1,2,1) #1 row, 2 columns, first plot
plt.plot([3,4,5,9],[55,44,2,8],'r--')
plt.title("The 1st Subplot")

#The second subplot
plt.subplot(1,2,2) #1 row, 2 columns, second plot
x = [1,2,3,4,5]
y = [3,5,7, 9, 10]
plt.plot(x,y,'g')
plt.title("The 2st Subplot")
# Out:
# Text(0.5, 1.0, 'The 2st Subplot')

# %% [markdown]
# 1. Create two sets of x,y coordinates. There should be 5 points in each set.
# 2. Plot both lines in separate plots in the same figure.
# 3. Make the first plot have a blue line and the second plot should have a red line.

# %%
x1 = [3,6,9,12,15]
x2 = [4,8,12,16,20]
y1 = [10,30,50,70,90]
y2 = [40,60,80,100,120]

plt.subplot(2,3,1)
plt.plot(x1,y1,'bo')

plt.subplot(2,3,2)
plt.plot(x2,y2,'ro')

plt.subplot(2,3,3)
plt.plot(x1,y2,'ro')

plt.subplot(2,3,4)
plt.plot(x1,y1,'bo')

plt.subplot(2,3,5)
plt.plot(x2,y2,'ro')

plt.subplot(2,3,6)
plt.plot(x1,y2,'ro')

# %% [markdown]
# **Plots in a single column**<br>
# You can change the subplot input parameters and make one plot above the other.

# %%
#Adding multiplots to one figure
plt.subplot(2,1,1) #2 rows, 1 column, first plot
plt.plot([3,4,5,9],[55,44,2,8],'r--')
plt.title("The 1st Subplot")

#The second subplot
plt.subplot(2,1,2) #2 rows, 1 column, second plot
x = [1,2,3,4,5]
y = [3,5,7, 9, 10]
plt.plot(x,y,'g')

# %% [markdown]
# #
# Pyplot uses a MatPlotLib method called bar() to make bar graphs. <br>These bar graphs use catagorical data.
# <br>
# Format for the bar method is: <br>
# >bar(x-axis values, y-axis values, color='color-name')

# %%
#Pyplot uses a MatPlotLib method called bar() to make bar graphs. 
#bar(x-axis values, y-axis values, color='color-name')

students=['Sue','Tom','Bill','Ann']
grades=[43,85,38,97]

plt.bar(students, grades)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# 1. Create a list of 5 classes.
# 2. Create a list of enrollment for the classes.
# 3. Create a bar chart to show enrollment per class.

# %%
classes=['Maths','Science','Social','English','Kannada']
enrollment=[43,85,38,97, 100]
plt.bar(classes, enrollment, color=('r','g','b','y'))
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# 1. Read the csv file called chordProgressions.csv. It is in
#
# 2. Create a bar chart using listing the progression quality and the 4th chord for 5 types of progression.

# %%
from numpy import genfromtxt
chords = genfromtxt("chordProgression.csv",  
                    delimiter=',',skip_header=1, dtype=[('1st chord','i1'),('2nd chord','i1') , ('3rd chord','i1'), ('4th chord','i1'), ('Progression Quality', 'S20')])
cReshape = chords.reshape(28,1)
cReshape = cReshape[0:5]
#cReshape = chords.reshape(1:5)
#print(cReshape)
#print(cReshape[0][0])

plt.figure(figsize=(15,2))
fourthChords = []
progressionQuality = []
print("size=",len(cReshape))
for i in range(len(cReshape)):
  #print(cReshape[i][0][3])
  fourthChords.append(cReshape[i][0][3])
  #print(cReshape[i][0][4])
  progressionQuality.append(cReshape[i][0][4])

plt.bar(progressionQuality, fourthChords, color=('r','y'))
# Out:
# size= 5
# <BarContainer object of 5 artists>

# %% [markdown]
# # **Heat Maps**
#
# reference: https://matplotlib.org/3.1.1/gallery/images_contours_and_fields/image_annotated_heatmap.html

# %%
import numpy as np
import numpy.random
import matplotlib
import matplotlib.pyplot as plt
#from matplotlib.ticker import FormatStrFormatter

# %%
vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])

# %%
fig, ax = plt.subplots()
im = ax.imshow(harvest)
# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries
ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)
# Out:
# [Text(0, 0, 'cucumber'),
#  Text(0, 1, 'tomato'),
#  Text(0, 2, 'lettuce'),
#  Text(0, 3, 'asparagus'),
#  Text(0, 4, 'potato'),
#  Text(0, 5, 'wheat'),
#  Text(0, 6, 'barley')]

# %%
fig, ax = plt.subplots()
im = ax.imshow(harvest)

# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries
ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")
# Create colorbar
cbarlabel = "Legend"
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom")

ax.set_title("Harvest of local farmers (in tons/year)")
plt.figure(figsize=(40,40))
plt.show()

# %% [markdown]
# ## Creating Different Types of Graphs with Pyplot

# %% [markdown]
# ### 1) Histogram
# Histograms are a very common type of plots when we are looking at data like height and weight, stock prices, waiting time for a customer, etc which are continuous in nature. Histogram’s data is plotted within a range against its frequency. Histograms are very commonly occurring graphs in probability and statistics and form the basis for various distributions like the normal -distribution, t-distribution, etc. In the following example, we generate a random continuous data of 1000 entries and plot it against its frequency with the data divided into 10 equal strata. We have used NumPy’s random.randn() method which generates data with the properties of a standard normal distribution i.e. mean = 0 and standard deviation = 1, and hence the histogram looks like a normal distribution curve.

# %%
# Plot Histogram
x = np.random.randn(1000)

plt.title('Histogram')
plt.xlabel('Random Data') # Add an x-label to the axes.
plt.ylabel('Frequency') # Add an y-label to the axes.
plt.hist(x, 10)  # 10 is the number of bins
plt.show()

# %%
# Population Histogram
plt.title('Population Histogram')
plt.xlabel('Population') # Add an x-label to the axes.
plt.ylabel('Frequency') # Add an y-label to the axes.
plt.hist(population, 100)  # 10 is the number of bins
plt.show()

# %%
# Area Histogram
plt.title('Area Histogram')
plt.xlabel('Area') # Add an x-label to the axes.
plt.ylabel('Frequency') # Add an y-label to the axes.
plt.hist(area, 50)  # 10 is the number of bins
plt.show()

# %%
# Plot Histogram
x = np.random.randn(1000)

plt.title('Histogram')
plt.xlabel('Random Data') # Add an x-label to the axes.
plt.ylabel('Frequency') # Add an y-label to the axes.
plt.hist(x, 100)  # 10 is the number of bins
plt.show()

# %% [markdown]
# ### 2) Scatter Plots
# Scatter plots are widely used graphs, especially they come in handy in visualizing a problem of regression. In the following example, we feed in arbitrarily created data of height and weight and plot them against each other. We used xlim() and ylim() methods to set the limits of X-axis and Y-axis respectively.

# %%
# Scatter Plot
height = np.array([167,170,149,165,155,180,166,146,159,185,145,168,172,181,169])
weight = np.array([86,74,66,78,68,79,90,73,76,8,66,84,67,84,77])

plt.xlim(140,200)
plt.ylim(60,100)
plt.scatter(height, weight)  # Scatter Plot 
plt.title("Scatter Plot")
plt.xlabel('Height') # Add an x-label to the axes.
plt.ylabel('Weight') # Add an y-label to the axes.
plt.show()

# %% [markdown]
# ### 3) Pie Charts
# One more basic type of chart is a Pie chart which can be made using the method <i>pie()</i> We can also pass in arguments to customize our Pie chart to show shadow, explode a part of it, tilt it at an angle as follows:

# %%
# Pie Chart
firms = ['Firm A','Firm B','Firm C','Firm D','Firm E']
marketShare = [25,25,15,10,20]
Explode = [0,0.1,0,0,0]   # only "explode" the 2nd slice (i.e. 'Firm B')

plt.figure(figsize = (10,10))  # Set Figure size
plt.pie(marketShare,      # data
        explode=Explode,  # only "explode" the 2nd slice (i.e. 'Firm B')
        labels=firms,     # labels
        shadow=True,      # drop-shadow
        startangle=45)    # startangle = 90 such that everything is rotated counter-clockwise by 90 degrees 
plt.title("Scatter Plot")
plt.axis('equal')  # Add an x-label to the axes.
plt.legend(title='List of Firms') # Add an y-label to the axes.
plt.show()

# %% [markdown]
# ### 4) Bar Graphs
# Bar graphs are one of the most common types of graphs and are used to show data associated with the categorical variables. Pyplot provides a method <i>bar()</i> to make bar graphs which take arguments: categorical variables, their values and color (if you want to specify any).

# %%
# Bar Graph
x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy = [5, 6, 15, 22, 24, 8]

plt.figure(figsize = (10,5))  # Set Figure size
plt.bar(x, energy, color='green')
plt.xlabel("Energy Source")
plt.ylabel("Energy Output (GJ)")
plt.title("Energy output from various fuel sources")

plt.show()

# %%
# Bar Graph for Country Area

# Get list of countires
#country = extractField("UN.txt", 1)  # Get country

plt.figure(figsize = (20,5))  # Set Figure size
plt.bar(country[0:10], area[0:10],  color='green')
plt.xlabel("Country")
plt.ylabel("Area")
plt.title("Area by 10 Countries")

plt.show()

# %%
# Bar Graph - Error Bar
x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy = [5, 6, 15, 22, 24, 8]
variance = [1, 2, 7, 4, 2, 3]

plt.figure(figsize = (10,5))  # Set Figure size
plt.bar(x, energy, color='green',  yerr=variance)
plt.xlabel("Energy Source")
plt.ylabel("Energy Output (GJ)")
plt.title("Energy output from various fuel sources")

plt.show()

# %%
# Horizontal Bar Graph - Error Bar
x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy = [5, 6, 15, 22, 24, 8]
variance = [1, 2, 7, 4, 2, 3]

plt.figure(figsize = (10,5))  # Set Figure size
plt.barh(x, energy, color='green',  xerr=variance)
plt.xlabel("Energy Source")
plt.ylabel("Energy Output (GJ)")
plt.title("Energy output from various fuel sources")

plt.show()

# %% [markdown]
# ### Bar Chart with Multiple X’s
# To create horizontally stacked bar graphs we use the bar() method twice and pass the arguments where we mention the index and width of our bar graphs in order to horizontally stack them together. Also, notice the use of two other methods legend() which is used to show the legend of the graph and xticks() to label our x-axis based on the position of our bars.

# %%
# Bar Graph
x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy2019 = [5, 6, 15, 22, 24, 8]
energy2018 = [4, 5, 11, 24, 28, 6]

index = np.arange(6)
width = 0.35

plt.figure(figsize = (10,5))  # Set Figure size
plt.bar(index, energy2018, width, color='green', label='2018')
plt.bar(index + width, energy2019, width, color='blue', label='2019',)

plt.title("Energy output from various fuel sources")
plt.xlabel("Energy Source")
plt.ylabel("Energy Output (GJ)")
plt.xticks(index + width/2, x)
plt.legend(loc='best')

plt.show()

# %% [markdown]
# ### Stack Bar Charts
# Similarly, to vertically stack the bar graphs together, we can use an argument bottom and mention the bar graph which we want to stack below as its value.

# %%
# Bar Graph
x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy2019 = [5, 6, 15, 22, 24, 8]
energy2018 = [4, 5, 11, 24, 28, 6]

index = np.arange(6)
width = 0.35

plt.figure(figsize = (10,5))  # Set Figure size
plt.bar(index, energy2018, width, color='green', label='2018')
plt.bar(index, energy2019, width, color='blue', label='2019', bottom=energy2018)

plt.title("Energy output from various fuel sources")
plt.xlabel("Energy Source")
plt.ylabel("Energy Output (GJ)")
plt.xticks(index, x)
plt.legend(loc='best')

plt.show()
